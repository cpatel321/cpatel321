# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
import scipy

# %% [markdown]
# # Question 1
# Plot the PMF and CDF of Bernoulli, Geometric, Binomial, and Poission random variables. Choose various values of parameters.

# %%
# bernauli random variable
# for p=0.5
p=0.5
bernauli_distr=np.random.binomial(1,p,1000)
p=0.3
bernauli_distr1=np.random.binomial(1,p,1000)
p=0.7
bernauli_distr2=np.random.binomial(1,p,1000)
p=0.9
bernauli_distr3=np.random.binomial(1,p,1000)
# plot the pmf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(bernauli_distr)
plt.title("PMF of Bernauli random variable for p=0.5")
plt.subplot(2,2,2)
plt.hist(bernauli_distr1)
plt.title("PMF of Bernauli random variable for p=0.3")
plt.subplot(2,2,3)
plt.hist(bernauli_distr2)
plt.title("PMF of Bernauli random variable for p=0.7")
plt.subplot(2,2,4)
plt.hist(bernauli_distr3)
plt.title("PMF of Bernauli random variable for p=0.9")
plt.show()

# plot the cdf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(bernauli_distr,cumulative=True)
plt.title("CDF of Bernauli random variable for p=0.5")
plt.subplot(2,2,2)
plt.hist(bernauli_distr1,cumulative=True)
plt.title("CDF of Bernauli random variable for p=0.3")
plt.subplot(2,2,3)
plt.hist(bernauli_distr2,cumulative=True)
plt.title("CDF of Bernauli random variable for p=0.7")
plt.subplot(2,2,4)
plt.hist(bernauli_distr3,cumulative=True)
plt.title("CDF of Bernauli random variable for p=0.9")
plt.show()

# for geometric random variable
# for p=0.5
p=0.5
geometric_distr=np.random.geometric(p,1000)
p=0.3
geometric_distr1=np.random.geometric(p,1000)
p=0.7
geometric_distr2=np.random.geometric(p,1000)
p=0.9
geometric_distr3=np.random.geometric(p,1000)
# plot the pmf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(geometric_distr)
plt.title("PMF of Geometric random variable for p=0.5")
plt.subplot(2,2,2)
plt.hist(geometric_distr1)
plt.title("PMF of Geometric random variable for p=0.3")
plt.subplot(2,2,3)
plt.hist(geometric_distr2)
plt.title("PMF of Geometric random variable for p=0.7")
plt.subplot(2,2,4)
plt.hist(geometric_distr3)
plt.title("PMF of Geometric random variable for p=0.9")
plt.show()
# cdf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(geometric_distr,cumulative=True)
plt.title("CDF of Geometric random variable for p=0.5")
plt.subplot(2,2,2)
plt.hist(geometric_distr1,cumulative=True)
plt.title("CDF of Geometric random variable for p=0.3")
plt.subplot(2,2,3)
plt.hist(geometric_distr2,cumulative=True)
plt.title("CDF of Geometric random variable for p=0.7")
plt.subplot(2,2,4)
plt.hist(geometric_distr3,cumulative=True)
plt.title("CDF of Geometric random variable for p=0.9")
plt.show()

# for binomial random variable
# for p=0.5
p=0.5
binomial_distr=np.random.binomial(10,p,1000)
p=0.3
binomial_distr1=np.random.binomial(10,p,1000)
p=0.7
binomial_distr2=np.random.binomial(10,p,1000)
p=0.9
binomial_distr3=np.random.binomial(10,p,1000)
# plot the pmf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(binomial_distr)
plt.title("PMF of Binomial random variable for p=0.5")
plt.subplot(2,2,2)
plt.hist(binomial_distr1)
plt.title("PMF of Binomial random variable for p=0.3")
plt.subplot(2,2,3)
plt.hist(binomial_distr2)
plt.title("PMF of Binomial random variable for p=0.7")
plt.subplot(2,2,4)
plt.hist(binomial_distr3)
plt.title("PMF of Binomial random variable for p=0.9")
plt.show()
# cdf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(binomial_distr,cumulative=True)
plt.title("CDF of Binomial random variable for p=0.5")
plt.subplot(2,2,2)
plt.hist(binomial_distr1,cumulative=True)
plt.title("CDF of Binomial random variable for p=0.3")
plt.subplot(2,2,3)
plt.hist(binomial_distr2,cumulative=True)
plt.title("CDF of Binomial random variable for p=0.7")
plt.subplot(2,2,4)
plt.hist(binomial_distr3,cumulative=True)
plt.title("CDF of Binomial random variable for p=0.9")
plt.show()

# for poisson random variable
# for lambda=5
lam=5
poisson_distr=np.random.poisson(lam,1000)
lam=3
poisson_distr1=np.random.poisson(lam,1000)
lam=7
poisson_distr2=np.random.poisson(lam,1000)
lam=9
poisson_distr3=np.random.poisson(lam,1000)
# plot the pmf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(poisson_distr)
plt.title("PMF of Poisson random variable for lambda=5")
plt.subplot(2,2,2)
plt.hist(poisson_distr1)
plt.title("PMF of Poisson random variable for lambda=3")
plt.subplot(2,2,3)
plt.hist(poisson_distr2)
plt.title("PMF of Poisson random variable for lambda=7")
plt.subplot(2,2,4)
plt.hist(poisson_distr3)
plt.title("PMF of Poisson random variable for lambda=9")
plt.show()
# cdf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(poisson_distr,cumulative=True)
plt.title("CDF of Poisson random variable for lambda=5")
plt.subplot(2,2,2)
plt.hist(poisson_distr1,cumulative=True)
plt.title("CDF of Poisson random variable for lambda=3")
plt.subplot(2,2,3)
plt.hist(poisson_distr2,cumulative=True)
plt.title("CDF of Poisson random variable for lambda=7")
plt.subplot(2,2,4)
plt.hist(poisson_distr3,cumulative=True)
plt.title("CDF of Poisson random variable for lambda=9")
plt.show()

# %% [markdown]
# # Question 2
# Show the equivalence and the difference between various choices of parameters for Binomial and Poission distributions. Use both PMF and CDF.

# %%
# Show the equivalence and the difference between various choices of parameters for Binomial and Poission distributions. Use both PMF and CDF.
binomial_distri=np.random.binomial(10,0.5,1000)
poisson_distri=np.random.poisson(5,1000)
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(binomial_distri)
plt.title("PMF of Binomial random variable for n=10 and p=0.5")
plt.subplot(2,2,2)
plt.hist(poisson_distri)
plt.title("PMF of Poisson random variable for lambda=5")
plt.subplot(2,2,3)
plt.hist(binomial_distri,cumulative=True)
plt.title("CDF of Binomial random variable for n=10 and p=0.5")
plt.subplot(2,2,4)
plt.hist(poisson_distri,cumulative=True)
plt.title("CDF of Poisson random variable for lambda=5")
plt.show()

# %% [markdown]
# # Question 3
# Read an image and add different amounts of Gaussian Noise and display the corrupted images.

# %%
import copy
# download the image from https://raw.githubusercontent.com/cpatel321/cpatel321/main/Lalminar.jpg
img = cv2.imread('Lalminar.jpg', 0)
mean = 0
plt.figure(figsize=(20,20))
plt.subplot(1,5,1)
var=0
sigma = var**0.5
gaussian_array = np.random.normal(mean, sigma, (img.shape))
gaussian_added=gaussian_array+copy.deepcopy(img)
plt.imshow(gaussian_added,cmap='gray')
plt.title("Original image")

plt.xticks([])
plt.yticks([])


plt.subplot(1,5,2)
var=20
sigma = var**0.5
gaussian_array = np.random.normal(mean, sigma, (img.shape))
gaussian_added=gaussian_array+copy.deepcopy(img)
plt.imshow(gaussian_added,cmap='gray') 
plt.title("Variance=20")
plt.xticks([])
plt.yticks([])

plt.subplot(1,5,3)
var=50
sigma = var**0.5
gaussian_array = np.random.normal(mean, sigma, (img.shape))
gaussian_added=gaussian_array+copy.deepcopy(img)
plt.imshow(gaussian_added,cmap='gray')
plt.title("Variance=50")
plt.xticks([])
plt.yticks([])

plt.subplot(1,5,4)
var=70
sigma = var**0.5
gaussian_array = np.random.normal(mean, sigma, (img.shape))
gaussian_added=gaussian_array+copy.deepcopy(img)
plt.imshow(gaussian_added,cmap='gray')
plt.title("Variance=70")
plt.xticks([])
plt.yticks([])


plt.subplot(1,5,5)
var=100
sigma = var**0.5
gaussian_array = np.random.normal(mean, sigma, (img.shape))
gaussian_added=gaussian_array+copy.deepcopy(img)
plt.imshow(gaussian_added,cmap='gray')
plt.title("Variance=100")
plt.xticks([])
plt.yticks([])

plt.show()

# %% [markdown]
# # Question 4
# Plot the PDF and CDF of the following random variables for different parameter values.
# - Uniform
# - Exponential
# - Rayleigh
# - Laplacian
# - Gaussian (Normal)
# - Chi-square
# - Erlang a
# - Log-normal
# - Cauchy
# - Beta
# - Weibull

# %% [markdown]
# # Acknowledgement
# I don't know most of the distribution and I still don't know many of the distributions used in first and this question. I have used numpy and scipy's documentations and many 3rd party programming sites like geeksforggeeks. And special thanks to openai.

# %%
# for uniform random variable
uniform_distr=np.random.uniform(0,1,1000)
uniform_distr1=np.random.uniform(0,2,1000)
uniform_distr2=np.random.uniform(0,3,1000)
uniform_distr3=np.random.uniform(0,4,1000)
# plot the pmf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(uniform_distr)
plt.title("PMF of Uniform random variable for a=0 and b=1")
plt.subplot(2,2,2)
plt.hist(uniform_distr1)
plt.title("PMF of Uniform random variable for a=0 and b=2")
plt.subplot(2,2,3)
plt.hist(uniform_distr2)
plt.title("PMF of Uniform random variable for a=0 and b=3")
plt.subplot(2,2,4)
plt.hist(uniform_distr3)
plt.title("PMF of Uniform random variable for a=0 and b=4")
plt.show()
# plot the cdf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(uniform_distr,cumulative=True)
plt.title("CDF of Uniform random variable for a=0 and b=1")
plt.subplot(2,2,2)
plt.hist(uniform_distr1,cumulative=True)
plt.title("CDF of Uniform random variable for a=0 and b=2")
plt.subplot(2,2,3)
plt.hist(uniform_distr2,cumulative=True)
plt.title("CDF of Uniform random variable for a=0 and b=3")
plt.subplot(2,2,4)
plt.hist(uniform_distr3,cumulative=True)
plt.title("CDF of Uniform random variable for a=0 and b=4")
plt.show()

# for exponential random variable
np.random.exponential()
exponential_distr=np.random.exponential(1,1000)
exponential_distr1=np.random.exponential(2,1000)
exponential_distr2=np.random.exponential(3,1000)
exponential_distr3=np.random.exponential(4,1000)
# plot the pmf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(exponential_distr)
plt.title("PMF of Exponential random variable for lambda=1")
plt.subplot(2,2,2)
plt.hist(exponential_distr1)
plt.title("PMF of Exponential random variable for lambda=2")
plt.subplot(2,2,3)
plt.hist(exponential_distr2)
plt.title("PMF of Exponential random variable for lambda=3")
plt.subplot(2,2,4)
plt.hist(exponential_distr3)
plt.title("PMF of Exponential random variable for lambda=4")
plt.show()
# plot the cdf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(exponential_distr,cumulative=True)
plt.title("CDF of Exponential random variable for lambda=1")
plt.subplot(2,2,2)
plt.hist(exponential_distr1,cumulative=True)
plt.title("CDF of Exponential random variable for lambda=2")
plt.subplot(2,2,3)
plt.hist(exponential_distr2,cumulative=True)
plt.title("CDF of Exponential random variable for lambda=3")
plt.subplot(2,2,4)
plt.hist(exponential_distr3,cumulative=True)
plt.title("CDF of Exponential random variable for lambda=4")
plt.show()

# for rayleigh random variable
rayleigh_distr=np.random.rayleigh(1,1000)
rayleigh_distr1=np.random.rayleigh(2,1000)
rayleigh_distr2=np.random.rayleigh(3,1000)
rayleigh_distr3=np.random.rayleigh(4,1000)
# plot the pmf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(rayleigh_distr)
plt.title("PMF of Rayleigh random variable for sigma=1")
plt.subplot(2,2,2)
plt.hist(rayleigh_distr1)
plt.title("PMF of Rayleigh random variable for sigma=2")
plt.subplot(2,2,3)
plt.hist(rayleigh_distr2)
plt.title("PMF of Rayleigh random variable for sigma=3")
plt.subplot(2,2,4)
plt.hist(rayleigh_distr3)
plt.title("PMF of Rayleigh random variable for sigma=4")
plt.show()
# plot the cdf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(rayleigh_distr,cumulative=True)
plt.title("CDF of Rayleigh random variable for sigma=1")
plt.subplot(2,2,2)
plt.hist(rayleigh_distr1,cumulative=True)
plt.title("CDF of Rayleigh random variable for sigma=2")
plt.subplot(2,2,3)
plt.hist(rayleigh_distr2,cumulative=True)
plt.title("CDF of Rayleigh random variable for sigma=3")
plt.subplot(2,2,4)
plt.hist(rayleigh_distr3,cumulative=True)
plt.title("CDF of Rayleigh random variable for sigma=4")
plt.show()

# for laplacian random variable
laplacian_distr=np.random.laplace(1,1,1000)
laplacian_distr1=np.random.laplace(2,2,1000)
laplacian_distr2=np.random.laplace(3,3,1000)
laplacian_distr3=np.random.laplace(4,4,1000)
# plot the pmf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(laplacian_distr)
plt.title("PMF of Laplacian random variable for mu=1 and b=1")
plt.subplot(2,2,2)
plt.hist(laplacian_distr1)
plt.title("PMF of Laplacian random variable for mu=2 and b=2")
plt.subplot(2,2,3)
plt.hist(laplacian_distr2)
plt.title("PMF of Laplacian random variable for mu=3 and b=3")
plt.subplot(2,2,4)
plt.hist(laplacian_distr3)
plt.title("PMF of Laplacian random variable for mu=4 and b=4")
plt.show()
# plot the cdf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(laplacian_distr,cumulative=True)
plt.title("CDF of Laplacian random variable for mu=1 and b=1")
plt.subplot(2,2,2)
plt.hist(laplacian_distr1,cumulative=True)
plt.title("CDF of Laplacian random variable for mu=2 and b=2")
plt.subplot(2,2,3)
plt.hist(laplacian_distr2,cumulative=True)
plt.title("CDF of Laplacian random variable for mu=3 and b=3")
plt.subplot(2,2,4)
plt.hist(laplacian_distr3,cumulative=True)
plt.title("CDF of Laplacian random variable for mu=4 and b=4")
plt.show()

# for Gaussian(normal) random variable
normal_distr=np.random.normal(1,1,1000)
normal_distr1=np.random.normal(2,2,1000)
normal_distr2=np.random.normal(3,3,1000)
normal_distr3=np.random.normal(4,4,1000)
# plot the pmf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(normal_distr)
plt.title("PMF of Normal random variable for mu=1 and sigma=1")
plt.subplot(2,2,2)
plt.hist(normal_distr1)
plt.title("PMF of Normal random variable for mu=2 and sigma=2")
plt.subplot(2,2,3)
plt.hist(normal_distr2)
plt.title("PMF of Normal random variable for mu=3 and sigma=3")
plt.subplot(2,2,4)
plt.hist(normal_distr3)
plt.title("PMF of Normal random variable for mu=4 and sigma=4")
plt.show()
# plot the cdf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(normal_distr,cumulative=True)
plt.title("CDF of Normal random variable for mu=1 and sigma=1")
plt.subplot(2,2,2)
plt.hist(normal_distr1,cumulative=True)
plt.title("CDF of Normal random variable for mu=2 and sigma=2")
plt.subplot(2,2,3)
plt.hist(normal_distr2,cumulative=True)
plt.title("CDF of Normal random variable for mu=3 and sigma=3")
plt.subplot(2,2,4)
plt.hist(normal_distr3,cumulative=True)
plt.title("CDF of Normal random variable for mu=4 and sigma=4")
plt.show()

# for chi-square random variable
chisquare_distr=np.random.chisquare(1,1000)
chisquare_distr1=np.random.chisquare(2,1000)
chisquare_distr2=np.random.chisquare(3,1000)
chisquare_distr3=np.random.chisquare(4,1000)
# plot the pmf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(chisquare_distr)
plt.title("PMF of Chi-square random variable for df=1")
plt.subplot(2,2,2)
plt.hist(chisquare_distr1)
plt.title("PMF of Chi-square random variable for df=2")
plt.subplot(2,2,3)
plt.hist(chisquare_distr2)
plt.title("PMF of Chi-square random variable for df=3")
plt.subplot(2,2,4)
plt.hist(chisquare_distr3)
plt.title("PMF of Chi-square random variable for df=4")
plt.show()
# plot the cdf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(chisquare_distr,cumulative=True)
plt.title("CDF of Chi-square random variable for df=1")
plt.subplot(2,2,2)
plt.hist(chisquare_distr1,cumulative=True)
plt.title("CDF of Chi-square random variable for df=2")
plt.subplot(2,2,3)
plt.hist(chisquare_distr2,cumulative=True)
plt.title("CDF of Chi-square random variable for df=3")
plt.subplot(2,2,4)
plt.hist(chisquare_distr3,cumulative=True)
plt.title("CDF of Chi-square random variable for df=4")
plt.show()

# for erlang random variable
erlang_distr=scipy.stats.erlang.rvs(1,1,1000)
erlang_distr1=scipy.stats.erlang.rvs(2,2,1000)
erlang_distr2=scipy.stats.erlang.rvs(3,3,1000)
erlang_distr3=scipy.stats.erlang.rvs(4,4,1000)

# plot the pmf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(erlang_distr)
plt.title("PMF of Erlang random variable for k=1 and lambda=1")
plt.subplot(2,2,2)
plt.hist(erlang_distr1)
plt.title("PMF of Erlang random variable for k=2 and lambda=2")
plt.subplot(2,2,3)
plt.hist(erlang_distr2)
plt.title("PMF of Erlang random variable for k=3 and lambda=3")
plt.subplot(2,2,4)
plt.hist(erlang_distr3)
plt.title("PMF of Erlang random variable for k=4 and lambda=4")
plt.show()
# plot the cdf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(erlang_distr,cumulative=True)
plt.title("CDF of Erlang random variable for k=1 and lambda=1")
plt.subplot(2,2,2)
plt.hist(erlang_distr1,cumulative=True)
plt.title("CDF of Erlang random variable for k=2 and lambda=2")
plt.subplot(2,2,3)
plt.hist(erlang_distr2,cumulative=True)
plt.title("CDF of Erlang random variable for k=3 and lambda=3")
plt.subplot(2,2,4)
plt.hist(erlang_distr3,cumulative=True)
plt.title("CDF of Erlang random variable for k=4 and lambda=4")
plt.show()


# for log-normal random variable
lognormal_distr=np.random.lognormal(1,1,1000)
lognormal_distr1=np.random.lognormal(1,2,1000)
lognormal_distr2=np.random.lognormal(1,3,1000)
lognormal_distr3=np.random.lognormal(1,4,1000)
# plot the pmf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(lognormal_distr)
plt.title("PMF of Lognormal random variable for mu=1 and sigma=1")
plt.subplot(2,2,2)
plt.hist(lognormal_distr1)
plt.title("PMF of Lognormal random variable for mu=1 and sigma=2")
plt.subplot(2,2,3)
plt.hist(lognormal_distr2)
plt.title("PMF of Lognormal random variable for mu=1 and sigma=3")
plt.subplot(2,2,4)
plt.hist(lognormal_distr3)
plt.title("PMF of Lognormal random variable for mu=1 and sigma=4")
plt.show()
# plot the cdf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(lognormal_distr,cumulative=True)
plt.title("CDF of Lognormal random variable for mu=1 and sigma=1")
plt.subplot(2,2,2)
plt.hist(lognormal_distr1,cumulative=True)
plt.title("CDF of Lognormal random variable for mu=2 and sigma=2")
plt.subplot(2,2,3)
plt.hist(lognormal_distr2,cumulative=True)
plt.title("CDF of Lognormal random variable for mu=3 and sigma=3")
plt.subplot(2,2,4)
plt.hist(lognormal_distr3,cumulative=True)
plt.title("CDF of Lognormal random variable for mu=4 and sigma=4")
plt.show()


# for cauchy random variable
cauchy_distr=scipy.stats.cauchy.rvs(0,1,1000)
cauchy_distr1=scipy.stats.cauchy.rvs(0,2,1000)
cauchy_distr2=scipy.stats.cauchy.rvs(0,3,1000)
cauchy_distr3=scipy.stats.cauchy.rvs(0,4,1000)
# plot the pmf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(cauchy_distr)
plt.title("PMF of Cauchy random variable for loc=0 and scale=1")
plt.subplot(2,2,2)
plt.hist(cauchy_distr1)
plt.title("PMF of Cauchy random variable for loc=0 and scale=2")
plt.subplot(2,2,3)
plt.hist(cauchy_distr2)
plt.title("PMF of Cauchy random variable for loc=0 and scale=3")
plt.subplot(2,2,4)
plt.hist(cauchy_distr3)
plt.title("PMF of Cauchy random variable for loc=0 and scale=4")
plt.show()
# plot the cdf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(cauchy_distr,cumulative=True)
plt.title("CDF of Cauchy random variable for loc=0 and scale=1")
plt.subplot(2,2,2)
plt.hist(cauchy_distr1,cumulative=True)
plt.title("CDF of Cauchy random variable for loc=0 and scale=2")
plt.subplot(2,2,3)
plt.hist(cauchy_distr2,cumulative=True)
plt.title("CDF of Cauchy random variable for loc=0 and scale=3")
plt.subplot(2,2,4)
plt.hist(cauchy_distr3,cumulative=True)
plt.title("CDF of Cauchy random variable for loc=0 and scale=4")
plt.show()



# for beta random variable
beta_distr=np.random.beta(1,1,1000)
beta_distr1=np.random.beta(1,2,1000)
beta_distr2=np.random.beta(1,3,1000)
beta_distr3=np.random.beta(1,4,1000)
# plot the pmf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(beta_distr)
plt.title("PMF of Beta random variable for alpha=1 and beta=1")
plt.subplot(2,2,2)
plt.hist(beta_distr1)
plt.title("PMF of Beta random variable for alpha=1 and beta=2")
plt.subplot(2,2,3)
plt.hist(beta_distr2)
plt.title("PMF of Beta random variable for alpha=1 and beta=3")
plt.subplot(2,2,4)
plt.hist(beta_distr3)
plt.title("PMF of Beta random variable for alpha=1 and beta=4")
plt.show()
# plot the cdf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(beta_distr,cumulative=True)
plt.title("CDF of Beta random variable for alpha=1 and beta=1")
plt.subplot(2,2,2)
plt.hist(beta_distr1,cumulative=True)
plt.title("CDF of Beta random variable for alpha=1 and beta=2")
plt.subplot(2,2,3)
plt.hist(beta_distr2,cumulative=True)
plt.title("CDF of Beta random variable for alpha=1 and beta=3")
plt.subplot(2,2,4)
plt.hist(beta_distr3,cumulative=True)
plt.title("CDF of Beta random variable for alpha=1 and beta=4")
plt.show()


# for weibull random variable
weibull_distr=np.random.weibull(1,1000)
weibull_distr1=np.random.weibull(2,1000)
weibull_distr2=np.random.weibull(3,1000)
weibull_distr3=np.random.weibull(4,1000)
# plot the pmf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(weibull_distr)
plt.title("PMF of Weibull random variable for alpha=1")
plt.subplot(2,2,2)
plt.hist(weibull_distr1)
plt.title("PMF of Weibull random variable for alpha=2")
plt.subplot(2,2,3)
plt.hist(weibull_distr2)
plt.title("PMF of Weibull random variable for alpha=3")
plt.subplot(2,2,4)
plt.hist(weibull_distr3)
plt.title("PMF of Weibull random variable for alpha=4")
plt.show()
# plot the cdf
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
plt.hist(weibull_distr,cumulative=True)
plt.title("CDF of Weibull random variable for alpha=1")
plt.subplot(2,2,2)
plt.hist(weibull_distr1,cumulative=True)
plt.title("CDF of Weibull random variable for alpha=2")
plt.subplot(2,2,3)
plt.hist(weibull_distr2,cumulative=True)
plt.title("CDF of Weibull random variable for alpha=3")
plt.subplot(2,2,4)
plt.hist(weibull_distr3,cumulative=True)
plt.title("CDF of Weibull random variable for alpha=4")
plt.show()

# %% [markdown]
# # Question 5
# Find the Expectation and variance for all the random variables in Question 1 & 4. Further, find and/or plot their characteristic functions.

# %%
# Find the Expectation and variance for all the random variables in Question 1 & 4. Further, find and/or plot their characteristic functions.

# for bernauli_distr
# expectation
print("Expectation of bernauli random variable is",np.mean(bernauli_distr))
# variance
print("Variance of bernauli random variable is",np.var(bernauli_distr))


# for geometric random variable
# expectation
print("Expectation of geometric random variable is",np.mean(geometric_distr))
# variance
print("Variance of geometric random variable is",np.var(geometric_distr))

# for binomial random variable
# expectation
print("Expectation of binomial random variable is",np.mean(binomial_distr))
# variance
print("Variance of binomial random variable is",np.var(binomial_distr))


# for poisson random variable
# expectation
print("Expectation of poisson random variable is",np.mean(poisson_distr))
# variance
print("Variance of poisson random variable is",np.var(poisson_distr))

# for uniform random variable
# expectation
print("Expectation of uniform random variable is",np.mean(uniform_distr))
# variance
print("Variance of uniform random variable is",np.var(uniform_distr))

# for exponential random variable
# expectation
print("Expectation of exponential random variable is",np.mean(exponential_distr))
# variance
print("Variance of exponential random variable is",np.var(exponential_distr))

# for rayleigh random variable
# expectation
print("Expectation of rayleigh random variable is",np.mean(rayleigh_distr))
# variance
print("Variance of rayleigh random variable is",np.var(rayleigh_distr))

# for laplacian random variable
# expectation
print("Expectation of laplacian random variable is",np.mean(laplacian_distr))
# variance
print("Variance of laplacian random variable is",np.var(laplacian_distr))

# for Gaussian random variable
# expectation
print("Expectation of Gaussian random variable is",np.mean(normal_distr))
# variance
print("Variance of Gaussian random variable is",np.var(normal_distr))

# for chi-square random variable
# expectation
print("Expectation of chi-square random variable is",np.mean(chisquare_distr))
# variance
print("Variance of chi-square random variable is",np.var(chisquare_distr))

# fir erlang random variable
# expectation
print("Expectation of erlang random variable is",np.mean(erlang_distr))
# variance
print("Variance of erlang random variable is",np.var(erlang_distr))

# for log-normal random variable
# expectation
print("Expectation of log-normal random variable is",np.mean(lognormal_distr))
# variance
print("Variance of log-normal random variable is",np.var(lognormal_distr))

# for cauchy random variable
# expectation
print("Expectation of cauchy random variable is",np.mean(cauchy_distr))
# variance
print("Variance of cauchy random variable is",np.var(cauchy_distr))


# for beta random variable
# expectation
print("Expectation of beta random variable is",np.mean(beta_distr))
# variance
print("Variance of beta random variable is",np.var(beta_distr))


# for weibull random variable
# expectation
print("Expectation of weibull random variable is",np.mean(weibull_distr))
# variance
print("Variance of weibull random variable is",np.var(weibull_distr))
# Out:
# Expectation of bernauli random variable is 0.491
# Variance of bernauli random variable is 0.24991899999999997
# Expectation of geometric random variable is 1.924
# Variance of geometric random variable is 1.866224
# Expectation of binomial random variable is 4.996
# Variance of binomial random variable is 2.5639839999999996
# Expectation of poisson random variable is 4.895
# Variance of poisson random variable is 4.821975
# Expectation of uniform random variable is 0.50645333101794
# Variance of uniform random variable is 0.08531401938519696
# Expectation of exponential random variable is 1.035861475800613
# Variance of exponential random variable is 0.9545469861819812
# Expectation of rayleigh random variable is 1.2552312819990052
# Variance of rayleigh random variable is 0.4207667764411039
# Expectation of laplacian random variable is 1.0925521649663255
# Variance of laplacian random variable is 2.3645239862310636
# Expectation of Gaussian random variable is 0.9475222676368397
# ...
